# %%
import pandas as pd
import overpass
import osmium
import pickle
import shapely.wkb as wkblib
import geopandas as gpd
import os
import folium
import branca
import json
from shapely.strtree import STRtree
from rtree import index
from shapely.geometry import Point, LineString, Polygon
from overpass import API
from sys import exc_info

# %% [markdown]
# # Getting Way-ids from Node-ids
#
# ORSM return node-id information but not Way-id. The latter is useful for is because it can bring `max speed` information and we can use it to infer traffic situations. The challenge is how to connect node-id to way-id and the possibilities analysed so far are:
#
# * Overpass API can bring us the closest way to a node as (lat,lon) [Reference](https://stackoverflow.com/questions/49944535/gps-to-way-id-matching-in-openstreetmaps) and [Reference2](https://wiki.openstreetmap.org/wiki/Overpass_API/Language_Guide#.22around.22_-_finding_something_near_something_else). It usually brings more than 1 *Way Id* but seems it could be used to extract max speed. However, using one of the free servers, it's **too slow**, taking ~1 second per query.  We could instantiate a local overpass API server installing Overpass on computers and installing data from OSM into a PostGIS databaes using [Osm2pgsql](https://wiki.openstreetmap.org/wiki/Osm2pgsql). However, it would be one extra server running an application
# * The same process but with [Mapbox Route-Annotator](https://github.com/mapbox/route-annotator). Haven't tried it yet but it seems it provide results as [this](https://github.com/Project-OSRM/osrm-backend/issues/5473) and this thread show
# * Use OSM API to retrieve node-id - way-id relationship like [here](https://help.openstreetmap.org/questions/19276/getting-way-id-from-its-nodes-id). This seems good but, as it's using a remote API, it could be susceptible to **number of calls limit**. Best was if this information was locally present.
# * Locally retrieve the needed information above from pbf. files and [pyosmium](https://docs.osmcode.org/pyosmium/latest/intro.html). It provides functionalities on how to process this kind of file from OSM and extract its elements, *i.e.*, node, ways and relatations. The idea is, if we manage to build a relation `from node-id to way-id` and its metadata, we could be able to locally lookup for informations

# %% [markdown]
# ## Overpass API Test

# %%
# OVERPASS API Test

# sample lat lons
locs = [[13.3709, 52.511582], [13.370935, 52.511495], [13.371089, 52.511118], [13.370534, 52.511023], [13.369092, 52.510785], [13.368213, 52.510637], [13.367225, 52.51047], [13.366241, 52.510303], [13.365261, 52.510138], [13.364288, 52.509976], [13.363238, 52.509806], [13.362312, 52.509797], [13.36137, 52.509818], [13.360447, 52.509839], [13.359551, 52.509866], [13.358561, 52.509903], [13.357576, 52.509904], [13.356591, 52.509846], [13.35558, 52.509759], [13.354612, 52.509675], [13.353614, 52.509598], [13.35269, 52.509652], [13.351723, 52.509703], [13.351658, 52.509698], [13.351651, 52.509698], [13.351651, 52.509698], [13.351651, 52.509698], [13.351247, 52.509667], [13.351701, 52.507865], [13.351849, 52.507144], [13.35194, 52.506447], [13.351857, 52.505827], [13.351611, 52.5052], [13.351165, 52.504597], [13.350724, 52.50405], [13.350334, 52.503632], [13.349591, 52.503095], [13.348905, 52.502719], [13.348216, 52.502395], [13.347481, 52.502031], [13.346909, 52.50163], [13.346656, 52.501425], [13.345665, 52.500639], [13.344568, 52.500303], [13.343555, 52.500203], [13.342811, 52.500151], [13.342745, 52.500147], [13.34245, 52.500133], [13.341416, 52.500024], [13.340411, 52.499888], [13.33937, 52.499728], [13.338208, 52.499525], [13.337167, 52.499371], [13.336297, 52.499328], [13.335804, 52.499351], [13.335765, 52.499356], [13.335589, 52.49938], [13.335025, 52.499145], [13.334343, 52.498559], [13.333567, 52.497966], [13.332765, 52.497437], [13.332016, 52.496986], [13.33142, 52.496629], [13.331094, 52.496448]]
locs = [[lat, lon] for lon,lat in locs]
locs[:2]
 
api = API()
  
locations=locs
for loc in locations:
    xx,yy=loc[0],loc[1]
    try:
        response = api.Get('way(around:5,{0},{1});'.format(loc[0],loc[1])) 
        print("For location with coordinates {0}, {1} found way IDs:".format(loc[0],loc[1]))
        print(response)
        print('\n')
    except:
        print("Got error: {0}".format(exc_info()))
# Out:
# For location with coordinates 52.511582, 13.3709 found way IDs:
# {"features": [{"geometry": null, "id": 7552152, "properties": {"abandoned:highway": "primary", "description": "historic, since 2006, former Entlastungsstra\u00dfe", "end_date": "2006", "name": "Entlastungsstra\u00dfe", "wikipedia": "de:Entlastungsstra\u00dfe"}, "type": "Feature"}, {"geometry": null, "id": 168934839, "properties": {"bicycle": "no", "foot": "no", "highway": "trunk", "horse": "no", "lanes": "3", "lit": "yes", "maxheight": "4", "maxspeed": "50", "motorroad": "yes", "name": "Tunnel Tiergarten Spreebogen", "oneway": "yes", "placement": "right_of:2", "postal_code": "10785", "surface": "asphalt", "toll": "no", "turn:lanes": "left|through|none"}, "type": "Feature"}], "type": "FeatureCollection"}
#
#
# For location with coordinates 52.511495, 13.370935 found way IDs:
# {"features": [{"geometry": null, "id": 7552152, "properties": {"abandoned:highway": "primary", "description": "historic, since 2006, former Entlastungsstra\u00dfe", "end_date": "2006", "name": "Entlastungsstra\u00dfe", "wikipedia": "de:Entlastungsstra\u00dfe"}, "type": "Feature"}, {"geometry": null, "id": 168934839, "properties": {"bicycle": "no", "foot": "no", "highway": "trunk", "horse": "no", "lanes": "3", "lit": "yes", "maxheight": "4", "maxspeed": "50", "motorroad": "yes", "name": "Tunnel Tiergarten Spreebogen", "oneway": "yes", "placement": "right_of:2", "postal_code": "10785", "surface": "asphalt", "toll": "no", "turn:lanes": "left|through|none"}, "type": "Feature"}], "type": "FeatureCollection"}
#
#
# For location with coordinates 52.511118, 13.371089 found way IDs:
# {"features": [{"geometry": null, "id": 37289166, "properties": {"cycleway": "lane", "highway": "secondary", "lanes": "3", "lanes:backward": "1", "lit": "yes", "maxspeed": "50", "name": "Tiergartenstra\u00dfe", "postal_code": "10785", "ref": "L 1137", "surface": "asphalt", "turn:lanes:forward": "left|through"}, "type": "Feature"}, {"geometry": null, "id": 48859717, "properties": {"bicycle": "no", "foot": "no", "highway": "trunk", "lanes": "2", "layer": "-2", "lit": "24/7", "maxspeed": "50", "maxspeed:variable": "obstruction", "motorroad": "yes", "name": "Tunnel Tiergarten Spreebogen", "oneway": "yes", "postal_code": "10785", "ref": "B 96", "surface": "asphalt", "tunnel": "yes"}, "type": "Feature"}, {"geometry": null, "id": 160971204, "properties": {"cycleway:right": "track", "highway": "primary", "lanes": "2", "lit": "yes", "maxspeed": "50", "name": "Ben-Gurion-Stra\u00dfe", "oneway": "yes", "postal_code": "10785", "surface": "asphalt"}, "type": "Feature"}, {"geometry": null, "id": 168934839, "properties": {"bicycle": "no", "foot": "no", "highway": "trunk", "horse": "no", "lanes": "3", "lit": "yes", "maxheight": "4", "maxspeed": "50", "motorroad": "yes", "name": "Tunnel Tiergarten Spreebogen", "oneway": "yes", "placement": "right_of:2", "postal_code": "10785", "surface": "asphalt", "toll": "no", "turn:lanes": "left|through|none"}, "type": "Feature"}, {"geometry": null, "id": 327462545, "properties": {"cycleway": "track", "highway": "secondary", "lanes": "4", "lanes:backward": "1", "lit": "yes", "maxspeed": "50", "name": "Tiergartenstra\u00dfe", "postal_code": "10785", "ref": "L 1137", "surface": "asphalt", "turn:lanes:forward": "left|through|right"}, "type": "Feature"}], "type": "FeatureCollection"}
#
#
# For location with coordinates 52.511023, 13.370534 found way IDs:
# {"features": [{"geometry": null, "id": 305589785, "properties": {"highway": "footway"}, "type": "Feature"}, {"geometry": null, "id": 327462545, "properties": {"cycleway": "track", "highway": "secondary", "lanes": "4", "lanes:backward": "1", "lit": "yes", "maxspeed": "50", "name": "Tiergartenstra\u00dfe", "postal_code": "10785", "ref": "L 1137", "surface": "asphalt", "turn:lanes:forward": "left|through|right"}, "type": "Feature"}], "type": "FeatureCollection"}
#
#
# For location with coordinates 52.510785, 13.369092 found way IDs:
# {"features": [{"geometry": null, "id": 25041360, "properties": {"cycleway": "lane", "highway": "secondary", "lit": "yes", "maxspeed": "50", "name": "Tiergartenstra\u00dfe", "postal_code": "10785", "ref": "L 1137", "surface": "asphalt"}, "type": "Feature"}], "type": "FeatureCollection"}
#
#
# For location with coordinates 52.510637, 13.368213 found way IDs:
# {"features": [{"geometry": null, "id": 461905068, "properties": {"cycleway": "lane", "cycleway:right": "yes", "highway": "secondary", "lit": "yes", "maxspeed": "50", "name": "Tiergartenstra\u00dfe", "postal_code": "10785", "ref": "L 1137", "surface": "asphalt"}, "type": "Feature"}], "type": "FeatureCollection"}
#
#
# For location with coordinates 52.51047, 13.367225 found way IDs:
# {"features": [{"geometry": null, "id": 461905068, "properties": {"cycleway": "lane", "cycleway:right": "yes", "highway": "secondary", "lit": "yes", "maxspeed": "50", "name": "Tiergartenstra\u00dfe", "postal_code": "10785", "ref": "L 1137", "surface": "asphalt"}, "type": "Feature"}], "type": "FeatureCollection"}
#
#
# For location with coordinates 52.510303, 13.366241 found way IDs:
# {"features": [{"geometry": null, "id": 461905068, "properties": {"cycleway": "lane", "cycleway:right": "yes", "highway": "secondary", "lit": "yes", "maxspeed": "50", "name": "Tiergartenstra\u00dfe", "postal_code": "10785", "ref": "L 1137", "surface": "asphalt"}, "type": "Feature"}], "type": "FeatureCollection"}
#
#
# For location with coordinates 52.510138, 13.365261 found way IDs:
# {"features": [{"geometry": null, "id": 461905067, "properties": {"cycleway": "lane", "highway": "secondary", "lanes": "3", "lanes:backward": "2", "lanes:forward": "1", "lit": "yes", "maxspeed": "50", "name": "Tiergartenstra\u00dfe", "postal_code": "10785", "ref": "L 1137", "surface": "asphalt", "turn:lanes:backward": "left|through"}, "type": "Feature"}], "type": "FeatureCollection"}
#
#
# For location with coordinates 52.509976, 13.364288 found way IDs:
# {"features": [{"geometry": null, "id": 279549312, "properties": {"cycleway": "lane", "cycleway:right": "yes", "highway": "secondary", "lit": "yes", "maxspeed": "50", "name": "Tiergartenstra\u00dfe", "postal_code": "10785", "ref": "L 1137", "surface": "asphalt"}, "type": "Feature"}], "type": "FeatureCollection"}
#
#
# For location with coordinates 52.509806, 13.363238 found way IDs:
# {"features": [{"geometry": null, "id": 106706442, "properties": {"highway": "service"}, "type": "Feature"}, {"geometry": null, "id": 279549312, "properties": {"cycleway": "lane", "cycleway:right": "yes", "highway": "secondary", "lit": "yes", "maxspeed": "50", "name": "Tiergartenstra\u00dfe", "postal_code": "10785", "ref": "L 1137", "surface": "asphalt"}, "type": "Feature"}], "type": "FeatureCollection"}
#
#
# For location with coordinates 52.509797, 13.362312 found way IDs:
# {"features": [{"geometry": null, "id": 279549312, "properties": {"cycleway": "lane", "cycleway:right": "yes", "highway": "secondary", "lit": "yes", "maxspeed": "50", "name": "Tiergartenstra\u00dfe", "postal_code": "10785", "ref": "L 1137", "surface": "asphalt"}, "type": "Feature"}], "type": "FeatureCollection"}
#
#
# For location with coordinates 52.509818, 13.36137 found way IDs:
# {"features": [{"geometry": null, "id": 279549312, "properties": {"cycleway": "lane", "cycleway:right": "yes", "highway": "secondary", "lit": "yes", "maxspeed": "50", "name": "Tiergartenstra\u00dfe", "postal_code": "10785", "ref": "L 1137", "surface": "asphalt"}, "type": "Feature"}], "type": "FeatureCollection"}
#
#
# For location with coordinates 52.509839, 13.360447 found way IDs:
# {"features": [{"geometry": null, "id": 279549312, "properties": {"cycleway": "lane", "cycleway:right": "yes", "highway": "secondary", "lit": "yes", "maxspeed": "50", "name": "Tiergartenstra\u00dfe", "postal_code": "10785", "ref": "L 1137", "surface": "asphalt"}, "type": "Feature"}], "type": "FeatureCollection"}
#
#
# For location with coordinates 52.509866, 13.359551 found way IDs:
# {"features": [{"geometry": null, "id": 279549312, "properties": {"cycleway": "lane", "cycleway:right": "yes", "highway": "secondary", "lit": "yes", "maxspeed": "50", "name": "Tiergartenstra\u00dfe", "postal_code": "10785", "ref": "L 1137", "surface": "asphalt"}, "type": "Feature"}], "type": "FeatureCollection"}
# For location with coordinates 52.509903, 13.358561 found way IDs:
# {"features": [{"geometry": null, "id": 279549312, "properties": {"cycleway": "lane", "cycleway:right": "yes", "highway": "secondary", "lit": "yes", "maxspeed": "50", "name": "Tiergartenstra\u00dfe", "postal_code": "10785", "ref": "L 1137", "surface": "asphalt"}, "type": "Feature"}], "type": "FeatureCollection"}
#
#
# For location with coordinates 52.509904, 13.357576 found way IDs:
# {"features": [{"geometry": null, "id": 279549312, "properties": {"cycleway": "lane", "cycleway:right": "yes", "highway": "secondary", "lit": "yes", "maxspeed": "50", "name": "Tiergartenstra\u00dfe", "postal_code": "10785", "ref": "L 1137", "surface": "asphalt"}, "type": "Feature"}, {"geometry": null, "id": 378130462, "properties": {"area:highway": "secondary", "surface": "asphalt"}, "type": "Feature"}], "type": "FeatureCollection"}
#
#
# For location with coordinates 52.509846, 13.356591 found way IDs:
# {"features": [{"geometry": null, "id": 279549312, "properties": {"cycleway": "lane", "cycleway:right": "yes", "highway": "secondary", "lit": "yes", "maxspeed": "50", "name": "Tiergartenstra\u00dfe", "postal_code": "10785", "ref": "L 1137", "surface": "asphalt"}, "type": "Feature"}], "type": "FeatureCollection"}
#
#
# For location with coordinates 52.509759, 13.35558 found way IDs:
# {"features": [{"geometry": null, "id": 66514461, "properties": {"cycleway": "lane", "highway": "secondary", "lanes": "2", "lit": "yes", "maxspeed": "50", "maxspeed:conditional": "30@(07:00-17:00)", "name": "Tiergartenstra\u00dfe", "postal_code": "10785", "ref": "L 1137", "sidewalk": "right", "source:maxspeed": "sign", "surface": "asphalt"}, "type": "Feature"}], "type": "FeatureCollection"}
#
#
# For location with coordinates 52.509675, 13.354612 found way IDs:
# {"features": [{"geometry": null, "id": 66514461, "properties": {"cycleway": "lane", "highway": "secondary", "lanes": "2", "lit": "yes", "maxspeed": "50", "maxspeed:conditional": "30@(07:00-17:00)", "name": "Tiergartenstra\u00dfe", "postal_code": "10785", "ref": "L 1137", "sidewalk": "right", "source:maxspeed": "sign", "surface": "asphalt"}, "type": "Feature"}], "type": "FeatureCollection"}
#
#
# For location with coordinates 52.509598, 13.353614 found way IDs:
# {"features": [{"geometry": null, "id": 66514461, "properties": {"cycleway": "lane", "highway": "secondary", "lanes": "2", "lit": "yes", "maxspeed": "50", "maxspeed:conditional": "30@(07:00-17:00)", "name": "Tiergartenstra\u00dfe", "postal_code": "10785", "ref": "L 1137", "sidewalk": "right", "source:maxspeed": "sign", "surface": "asphalt"}, "type": "Feature"}, {"geometry": null, "id": 378130464, "properties": {"area:highway": "secondary", "surface": "asphalt"}, "type": "Feature"}], "type": "FeatureCollection"}
#
#
# For location with coordinates 52.509652, 13.35269 found way IDs:
# {"features": [{"geometry": null, "id": 153376938, "properties": {"cycleway:right": "lane", "highway": "secondary", "lanes": "2", "lit": "yes", "maxspeed": "50", "maxspeed:conditional": "30@(07:00-17:00)", "name": "Tiergartenstra\u00dfe", "oneway": "yes", "postal_code": "10785", "ref": "L 1137", "source:maxspeed": "sign", "surface": "asphalt"}, "type": "Feature"}], "type": "FeatureCollection"}
#
#
# For location with coordinates 52.509703, 13.351723 found way IDs:
# {"features": [{"geometry": null, "id": 309602349, "properties": {"bicycle:lanes": "no|no|no|designated|yes", "cycleway:right": "lane", "highway": "secondary", "lanes": "4", "lit": "yes", "maxspeed": "50", "maxspeed:conditional": "30@(07:00-17:00)", "name": "Tiergartenstra\u00dfe", "oneway": "yes", "postal_code": "10785", "ref": "L 1137", "sidewalk": "right", "source:maxspeed": "sign", "surface": "asphalt", "turn:lanes": "left|through|through|through|right", "vehicle:lanes": "yes|yes|yes|no|yes"}, "type": "Feature"}, {"geometry": null, "id": 378130453, "properties": {"footway": "crossing", "highway": "footway", "lit": "no"}, "type": "Feature"}, {"geometry": null, "id": 378130457, "properties": {"area:highway": "primary", "junction": "yes", "surface": "asphalt"}, "type": "Feature"}, {"geometry": null, "id": 378130463, "properties": {"area:highway": "secondary", "surface": "asphalt"}, "type": "Feature"}, {"geometry": null, "id": 603901204, "properties": {"bicycle": "yes", "footway": "crossing", "highway": "footway", "lit": "no"}, "type": "Feature"}], "type": "FeatureCollection"}
#
#
# For location with coordinates 52.509698, 13.351658 found way IDs:
# {"features": [{"geometry": null, "id": 309602349, "properties": {"bicycle:lanes": "no|no|no|designated|yes", "cycleway:right": "lane", "highway": "secondary", "lanes": "4", "lit": "yes", "maxspeed": "50", "maxspeed:conditional": "30@(07:00-17:00)", "name": "Tiergartenstra\u00dfe", "oneway": "yes", "postal_code": "10785", "ref": "L 1137", "sidewalk": "right", "source:maxspeed": "sign", "surface": "asphalt", "turn:lanes": "left|through|through|through|right", "vehicle:lanes": "yes|yes|yes|no|yes"}, "type": "Feature"}, {"geometry": null, "id": 378130453, "properties": {"footway": "crossing", "highway": "footway", "lit": "no"}, "type": "Feature"}, {"geometry": null, "id": 378130457, "properties": {"area:highway": "primary", "junction": "yes", "surface": "asphalt"}, "type": "Feature"}, {"geometry": null, "id": 378130463, "properties": {"area:highway": "secondary", "surface": "asphalt"}, "type": "Feature"}, {"geometry": null, "id": 603901204, "properties": {"bicycle": "yes", "footway": "crossing", "highway": "footway", "lit": "no"}, "type": "Feature"}], "type": "FeatureCollection"}
#
#
# For location with coordinates 52.509698, 13.351651 found way IDs:
# {"features": [{"geometry": null, "id": 309602349, "properties": {"bicycle:lanes": "no|no|no|designated|yes", "cycleway:right": "lane", "highway": "secondary", "lanes": "4", "lit": "yes", "maxspeed": "50", "maxspeed:conditional": "30@(07:00-17:00)", "name": "Tiergartenstra\u00dfe", "oneway": "yes", "postal_code": "10785", "ref": "L 1137", "sidewalk": "right", "source:maxspeed": "sign", "surface": "asphalt", "turn:lanes": "left|through|through|through|right", "vehicle:lanes": "yes|yes|yes|no|yes"}, "type": "Feature"}, {"geometry": null, "id": 378130453, "properties": {"footway": "crossing", "highway": "footway", "lit": "no"}, "type": "Feature"}, {"geometry": null, "id": 378130457, "properties": {"area:highway": "primary", "junction": "yes", "surface": "asphalt"}, "type": "Feature"}, {"geometry": null, "id": 378130463, "properties": {"area:highway": "secondary", "surface": "asphalt"}, "type": "Feature"}, {"geometry": null, "id": 603901204, "properties": {"bicycle": "yes", "footway": "crossing", "highway": "footway", "lit": "no"}, "type": "Feature"}], "type": "FeatureCollection"}
#
#
# For location with coordinates 52.509698, 13.351651 found way IDs:
# {"features": [{"geometry": null, "id": 309602349, "properties": {"bicycle:lanes": "no|no|no|designated|yes", "cycleway:right": "lane", "highway": "secondary", "lanes": "4", "lit": "yes", "maxspeed": "50", "maxspeed:conditional": "30@(07:00-17:00)", "name": "Tiergartenstra\u00dfe", "oneway": "yes", "postal_code": "10785", "ref": "L 1137", "sidewalk": "right", "source:maxspeed": "sign", "surface": "asphalt", "turn:lanes": "left|through|through|through|right", "vehicle:lanes": "yes|yes|yes|no|yes"}, "type": "Feature"}, {"geometry": null, "id": 378130453, "properties": {"footway": "crossing", "highway": "footway", "lit": "no"}, "type": "Feature"}, {"geometry": null, "id": 378130457, "properties": {"area:highway": "primary", "junction": "yes", "surface": "asphalt"}, "type": "Feature"}, {"geometry": null, "id": 378130463, "properties": {"area:highway": "secondary", "surface": "asphalt"}, "type": "Feature"}, {"geometry": null, "id": 603901204, "properties": {"bicycle": "yes", "footway": "crossing", "highway": "footway", "lit": "no"}, "type": "Feature"}], "type": "FeatureCollection"}
#
#
# For location with coordinates 52.509698, 13.351651 found way IDs:
# {"features": [{"geometry": null, "id": 309602349, "properties": {"bicycle:lanes": "no|no|no|designated|yes", "cycleway:right": "lane", "highway": "secondary", "lanes": "4", "lit": "yes", "maxspeed": "50", "maxspeed:conditional": "30@(07:00-17:00)", "name": "Tiergartenstra\u00dfe", "oneway": "yes", "postal_code": "10785", "ref": "L 1137", "sidewalk": "right", "source:maxspeed": "sign", "surface": "asphalt", "turn:lanes": "left|through|through|through|right", "vehicle:lanes": "yes|yes|yes|no|yes"}, "type": "Feature"}, {"geometry": null, "id": 378130453, "properties": {"footway": "crossing", "highway": "footway", "lit": "no"}, "type": "Feature"}, {"geometry": null, "id": 378130457, "properties": {"area:highway": "primary", "junction": "yes", "surface": "asphalt"}, "type": "Feature"}, {"geometry": null, "id": 378130463, "properties": {"area:highway": "secondary", "surface": "asphalt"}, "type": "Feature"}, {"geometry": null, "id": 603901204, "properties": {"bicycle": "yes", "footway": "crossing", "highway": "footway", "lit": "no"}, "type": "Feature"}], "type": "FeatureCollection"}
# For location with coordinates 52.509667, 13.351247 found way IDs:
# {"features": [{"geometry": null, "id": 4615993, "properties": {"cycleway:right": "lane", "highway": "secondary", "lanes": "4", "lit": "yes", "maxspeed": "50", "name": "St\u00fclerstra\u00dfe", "oneway": "yes", "postal_code": "10785", "surface": "asphalt", "turn:lanes": "left|left|through|through"}, "type": "Feature"}, {"geometry": null, "id": 153373877, "properties": {"cycleway:right": "lane", "highway": "secondary", "lanes": "1", "lit": "yes", "maxspeed": "50", "name": "St\u00fclerstra\u00dfe", "oneway": "yes", "postal_code": "10787", "surface": "asphalt"}, "type": "Feature"}, {"geometry": null, "id": 153652996, "properties": {"cycleway:right": "track", "highway": "primary", "lanes": "4", "lit": "yes", "maxspeed": "50", "name": "Klingelh\u00f6ferstra\u00dfe", "oneway": "yes", "postal_code": "10785", "surface": "asphalt", "turn:lanes": "left|through|through|through"}, "type": "Feature"}, {"geometry": null, "id": 498333193, "properties": {"highway": "primary", "lanes": "4", "lit": "yes", "maxspeed": "50", "name": "Hofj\u00e4gerallee", "oneway": "yes", "postal_code": "10785", "surface": "asphalt", "turn:lanes": "left|through|through|through;right"}, "type": "Feature"}, {"geometry": null, "id": 603901207, "properties": {"highway": "cycleway", "lit": "yes"}, "type": "Feature"}], "type": "FeatureCollection"}
#
#
# For location with coordinates 52.507865, 13.351701 found way IDs:
# {"features": [{"geometry": null, "id": 309600202, "properties": {"highway": "primary", "lanes": "3", "lit": "yes", "maxspeed": "50", "name": "Klingelh\u00f6ferstra\u00dfe", "oneway": "yes", "postal_code": "10785", "sidewalk": "no", "surface": "asphalt"}, "type": "Feature"}], "type": "FeatureCollection"}
#
#
# For location with coordinates 52.507144, 13.351849 found way IDs:
# {"features": [{"geometry": null, "id": 309600202, "properties": {"highway": "primary", "lanes": "3", "lit": "yes", "maxspeed": "50", "name": "Klingelh\u00f6ferstra\u00dfe", "oneway": "yes", "postal_code": "10785", "sidewalk": "no", "surface": "asphalt"}, "type": "Feature"}], "type": "FeatureCollection"}
#
#
# For location with coordinates 52.506447, 13.35194 found way IDs:
# {"features": [{"geometry": null, "id": 309600202, "properties": {"highway": "primary", "lanes": "3", "lit": "yes", "maxspeed": "50", "name": "Klingelh\u00f6ferstra\u00dfe", "oneway": "yes", "postal_code": "10785", "sidewalk": "no", "surface": "asphalt"}, "type": "Feature"}], "type": "FeatureCollection"}
#
#
# For location with coordinates 52.505827, 13.351857 found way IDs:
# {"features": [{"geometry": null, "id": 4492320, "properties": {"CEMT": "I", "boat": "yes", "draft": "1.40", "maxspeed": "6", "name": "Landwehrkanal", "waterway": "canal"}, "type": "Feature"}, {"geometry": null, "id": 659112705, "properties": {"bridge": "yes", "cycleway:right": "track", "highway": "primary", "lanes": "4", "layer": "1", "lit": "yes", "maxspeed": "50", "name": "Herkulesbr\u00fccke", "oneway": "yes", "postal_code": "10785", "sidewalk": "right", "surface": "asphalt"}, "type": "Feature"}, {"geometry": null, "id": 678030549, "properties": {"bridge": "yes", "cycleway:right": "track", "highway": "primary", "lanes": "5", "layer": "1", "lit": "yes", "maxspeed": "50", "name": "Herkulesbr\u00fccke", "oneway": "yes", "postal_code": "10785", "sidewalk": "right", "surface": "asphalt", "turn:lanes": "left|left;through|none|none|none"}, "type": "Feature"}], "type": "FeatureCollection"}
#
#
# For location with coordinates 52.5052, 13.351611 found way IDs:
# {"features": [{"geometry": null, "id": 309600205, "properties": {"cycleway:right": "track", "highway": "primary", "lanes": "4", "lit": "yes", "maxspeed": "50", "name": "L\u00fctzowplatz", "oneway": "yes", "postal_code": "10785", "sidewalk": "right", "surface": "asphalt"}, "type": "Feature"}], "type": "FeatureCollection"}
#
#
# For location with coordinates 52.504597, 13.351165 found way IDs:
# {"features": [{"geometry": null, "id": 11607613, "properties": {"highway": "secondary", "lanes": "2", "lit": "yes", "maxspeed": "50", "name": "L\u00fctzowplatz", "oneway": "yes", "postal_code": "10785", "sidewalk": "no", "surface": "asphalt"}, "type": "Feature"}, {"geometry": null, "id": 678030953, "properties": {"cycleway:right": "track", "highway": "primary", "lanes": "4", "lit": "yes", "maxspeed": "50", "name": "L\u00fctzowplatz", "oneway": "yes", "postal_code": "10785", "sidewalk": "right", "surface": "asphalt"}, "type": "Feature"}, {"geometry": null, "id": 678030955, "properties": {"cycleway:right": "track", "highway": "primary", "lanes": "5", "lit": "yes", "maxspeed": "50", "name": "L\u00fctzowplatz", "oneway": "yes", "postal_code": "10785", "sidewalk": "right", "surface": "asphalt", "turn:lanes": "left|left;through|none|none|none"}, "type": "Feature"}], "type": "FeatureCollection"}
#
#
# For location with coordinates 52.50405, 13.350724 found way IDs:
# {"features": [{"geometry": null, "id": 11406328, "properties": {"cycleway:right": "track", "highway": "primary", "lanes": "4", "lit": "yes", "maxspeed": "50", "name": "Schillstra\u00dfe", "oneway": "yes", "postal_code": "10785", "sidewalk": "right", "surface": "asphalt"}, "type": "Feature"}, {"geometry": null, "id": 382360277, "properties": {"landuse": "residential"}, "type": "Feature"}], "type": "FeatureCollection"}
#
#
# For location with coordinates 52.503632, 13.350334 found way IDs:
# {"features": [{"geometry": null, "id": 11406328, "properties": {"cycleway:right": "track", "highway": "primary", "lanes": "4", "lit": "yes", "maxspeed": "50", "name": "Schillstra\u00dfe", "oneway": "yes", "postal_code": "10785", "sidewalk": "right", "surface": "asphalt"}, "type": "Feature"}, {"geometry": null, "id": 18892496, "properties": {"highway": "service", "lit": "yes", "maxspeed": "50", "surface": "asphalt"}, "type": "Feature"}, {"geometry": null, "id": 309600207, "properties": {"cycleway:right": "track", "highway": "primary", "lanes": "4", "lit": "yes", "maxspeed": "50", "name": "Schillstra\u00dfe", "oneway": "yes", "postal_code": "10785", "sidewalk": "right", "surface": "asphalt", "turn:lanes": "through|through|through|right"}, "type": "Feature"}], "type": "FeatureCollection"}
#
#
# For location with coordinates 52.503095, 13.349591 found way IDs:
# {"features": [{"geometry": null, "id": 24912613, "properties": {"cycleway:right": "lane", "highway": "secondary", "lanes": "4", "lit": "yes", "maxspeed": "50", "name": "Kurf\u00fcrstenstra\u00dfe", "oneway": "yes", "postal_code": "10785", "surface": "asphalt", "turn:lanes": "left|left|none|none"}, "type": "Feature"}, {"geometry": null, "id": 24912625, "properties": {"cycleway:right": "lane", "highway": "primary", "lanes": "4", "lit": "yes", "maxspeed": "50", "oneway": "yes", "postal_code": "10785", "surface": "asphalt"}, "type": "Feature"}, {"geometry": null, "id": 153151222, "properties": {"cycleway:right": "track", "highway": "primary", "lit": "yes", "maxspeed": "50", "name": "An der Urania", "oneway": "yes", "postal_code": "10787", "surface": "asphalt"}, "type": "Feature"}, {"geometry": null, "id": 335396340, "properties": {"cycleway:right": "no", "highway": "secondary", "lanes": "4", "lit": "yes", "maxspeed": "50", "name": "Kurf\u00fcrstenstra\u00dfe", "oneway": "yes", "postal_code": "10787", "sidewalk": "right", "sidewalk:right:bicycle": "yes", "surface": "asphalt", "turn:lanes": "left|left|none|none"}, "type": "Feature"}], "type": "FeatureCollection"}
#
#
# For location with coordinates 52.502719, 13.348905 found way IDs:
# {"features": [{"geometry": null, "id": 153151222, "properties": {"cycleway:right": "track", "highway": "primary", "lit": "yes", "maxspeed": "50", "name": "An der Urania", "oneway": "yes", "postal_code": "10787", "surface": "asphalt"}, "type": "Feature"}, {"geometry": null, "id": 382360350, "properties": {"landuse": "residential"}, "type": "Feature"}], "type": "FeatureCollection"}
#
#
# For location with coordinates 52.502395, 13.348216 found way IDs:
# {"features": [{"geometry": null, "id": 153151222, "properties": {"cycleway:right": "track", "highway": "primary", "lit": "yes", "maxspeed": "50", "name": "An der Urania", "oneway": "yes", "postal_code": "10787", "surface": "asphalt"}, "type": "Feature"}], "type": "FeatureCollection"}
# For location with coordinates 52.502031, 13.347481 found way IDs:
# {"features": [{"geometry": null, "id": 153151222, "properties": {"cycleway:right": "track", "highway": "primary", "lit": "yes", "maxspeed": "50", "name": "An der Urania", "oneway": "yes", "postal_code": "10787", "surface": "asphalt"}, "type": "Feature"}, {"geometry": null, "id": 382360350, "properties": {"landuse": "residential"}, "type": "Feature"}], "type": "FeatureCollection"}
#
#
# For location with coordinates 52.50163, 13.346909 found way IDs:
# {"features": [{"geometry": null, "id": 153151222, "properties": {"cycleway:right": "track", "highway": "primary", "lit": "yes", "maxspeed": "50", "name": "An der Urania", "oneway": "yes", "postal_code": "10787", "surface": "asphalt"}, "type": "Feature"}], "type": "FeatureCollection"}
#
#
# For location with coordinates 52.501425, 13.346656 found way IDs:
# {"features": [{"geometry": null, "id": 153151222, "properties": {"cycleway:right": "track", "highway": "primary", "lit": "yes", "maxspeed": "50", "name": "An der Urania", "oneway": "yes", "postal_code": "10787", "surface": "asphalt"}, "type": "Feature"}], "type": "FeatureCollection"}
#
#
# For location with coordinates 52.500639, 13.345665 found way IDs:
# {"features": [{"geometry": null, "id": 4436880, "properties": {"cycleway:right": "track", "highway": "secondary", "lanes": "2", "lit": "yes", "maxspeed": "50", "name": "Lietzenburger Stra\u00dfe", "note": "\u00dcbergeordnete Stra\u00dfe, Stufe II", "oneway": "yes", "postal_code": "10789", "surface": "asphalt"}, "type": "Feature"}, {"geometry": null, "id": 48491201, "properties": {"bicycle": "designated", "foot": "designated", "highway": "path", "segregated": "yes"}, "type": "Feature"}, {"geometry": null, "id": 48491203, "properties": {"bicycle": "designated", "foot": "designated", "highway": "path", "segregated": "yes"}, "type": "Feature"}, {"geometry": null, "id": 195851270, "properties": {"landuse": "grass"}, "type": "Feature"}, {"geometry": null, "id": 686558910, "properties": {"layer": "-1", "location": "underground", "operator": "Stromnetz Berlin", "power": "cable", "voltage": "110000"}, "type": "Feature"}], "type": "FeatureCollection"}
#
#
# For location with coordinates 52.500303, 13.344568 found way IDs:
# {"features": [{"geometry": null, "id": 4436880, "properties": {"cycleway:right": "track", "highway": "secondary", "lanes": "2", "lit": "yes", "maxspeed": "50", "name": "Lietzenburger Stra\u00dfe", "note": "\u00dcbergeordnete Stra\u00dfe, Stufe II", "oneway": "yes", "postal_code": "10789", "surface": "asphalt"}, "type": "Feature"}, {"geometry": null, "id": 26722415, "properties": {"landuse": "grass"}, "type": "Feature"}, {"geometry": null, "id": 684019403, "properties": {"highway": "footway"}, "type": "Feature"}, {"geometry": null, "id": 686558910, "properties": {"layer": "-1", "location": "underground", "operator": "Stromnetz Berlin", "power": "cable", "voltage": "110000"}, "type": "Feature"}], "type": "FeatureCollection"}
#
#
# For location with coordinates 52.500203, 13.343555 found way IDs:
# {"features": [{"geometry": null, "id": 4436880, "properties": {"cycleway:right": "track", "highway": "secondary", "lanes": "2", "lit": "yes", "maxspeed": "50", "name": "Lietzenburger Stra\u00dfe", "note": "\u00dcbergeordnete Stra\u00dfe, Stufe II", "oneway": "yes", "postal_code": "10789", "surface": "asphalt"}, "type": "Feature"}, {"geometry": null, "id": 382360374, "properties": {"landuse": "residential"}, "type": "Feature"}], "type": "FeatureCollection"}
#
#
# For location with coordinates 52.500151, 13.342811 found way IDs:
# {"features": [{"geometry": null, "id": 4436880, "properties": {"cycleway:right": "track", "highway": "secondary", "lanes": "2", "lit": "yes", "maxspeed": "50", "name": "Lietzenburger Stra\u00dfe", "note": "\u00dcbergeordnete Stra\u00dfe, Stufe II", "oneway": "yes", "postal_code": "10789", "surface": "asphalt"}, "type": "Feature"}, {"geometry": null, "id": 9610539, "properties": {"foot": "yes", "highway": "cycleway", "surface": "paving_stones"}, "type": "Feature"}, {"geometry": null, "id": 26722415, "properties": {"landuse": "grass"}, "type": "Feature"}], "type": "FeatureCollection"}
#
#
# For location with coordinates 52.500147, 13.342745 found way IDs:
# {"features": [{"geometry": null, "id": 4436880, "properties": {"cycleway:right": "track", "highway": "secondary", "lanes": "2", "lit": "yes", "maxspeed": "50", "name": "Lietzenburger Stra\u00dfe", "note": "\u00dcbergeordnete Stra\u00dfe, Stufe II", "oneway": "yes", "postal_code": "10789", "surface": "asphalt"}, "type": "Feature"}, {"geometry": null, "id": 9610539, "properties": {"foot": "yes", "highway": "cycleway", "surface": "paving_stones"}, "type": "Feature"}, {"geometry": null, "id": 26722415, "properties": {"landuse": "grass"}, "type": "Feature"}], "type": "FeatureCollection"}
#
#
# For location with coordinates 52.500133, 13.34245 found way IDs:
# {"features": [{"geometry": null, "id": 4436880, "properties": {"cycleway:right": "track", "highway": "secondary", "lanes": "2", "lit": "yes", "maxspeed": "50", "name": "Lietzenburger Stra\u00dfe", "note": "\u00dcbergeordnete Stra\u00dfe, Stufe II", "oneway": "yes", "postal_code": "10789", "surface": "asphalt"}, "type": "Feature"}, {"geometry": null, "id": 318889283, "properties": {"cycleway:right": "track", "highway": "secondary", "lanes": "3", "lit": "yes", "maxspeed": "50", "name": "Lietzenburger Stra\u00dfe", "note": "\u00dcbergeordnete Stra\u00dfe, Stufe II", "oneway": "yes", "postal_code": "10789", "surface": "asphalt", "turn:lanes": "left|through|none"}, "type": "Feature"}, {"geometry": null, "id": 382360374, "properties": {"landuse": "residential"}, "type": "Feature"}], "type": "FeatureCollection"}
#
#
# For location with coordinates 52.500024, 13.341416 found way IDs:
# {"features": [{"geometry": null, "id": 318889283, "properties": {"cycleway:right": "track", "highway": "secondary", "lanes": "3", "lit": "yes", "maxspeed": "50", "name": "Lietzenburger Stra\u00dfe", "note": "\u00dcbergeordnete Stra\u00dfe, Stufe II", "oneway": "yes", "postal_code": "10789", "surface": "asphalt", "turn:lanes": "left|through|none"}, "type": "Feature"}], "type": "FeatureCollection"}
#
#
# For location with coordinates 52.499888, 13.340411 found way IDs:
# {"features": [{"geometry": null, "id": 318889287, "properties": {"cycleway:right": "track", "highway": "secondary", "lanes": "2", "lit": "yes", "maxspeed": "50", "name": "Lietzenburger Stra\u00dfe", "note": "\u00dcbergeordnete Stra\u00dfe, Stufe II", "oneway": "yes", "postal_code": "10789", "surface": "asphalt"}, "type": "Feature"}], "type": "FeatureCollection"}
#
#
# For location with coordinates 52.499728, 13.33937 found way IDs:
# {"features": [{"geometry": null, "id": 4491977, "properties": {"highway": "secondary", "lit": "yes", "maxspeed": "50", "name": "Lietzenburger Stra\u00dfe", "oneway": "yes", "postal_code": "10789", "surface": "asphalt"}, "type": "Feature"}, {"geometry": null, "id": 26976439, "properties": {"highway": "residential", "lit": "yes", "maxspeed": "30", "name": "Passauer Stra\u00dfe", "oneway": "yes", "postal_code": "10789", "surface": "asphalt"}, "type": "Feature"}, {"geometry": null, "id": 318889287, "properties": {"cycleway:right": "track", "highway": "secondary", "lanes": "2", "lit": "yes", "maxspeed": "50", "name": "Lietzenburger Stra\u00dfe", "note": "\u00dcbergeordnete Stra\u00dfe, Stufe II", "oneway": "yes", "postal_code": "10789", "surface": "asphalt"}, "type": "Feature"}], "type": "FeatureCollection"}
#
#
# For location with coordinates 52.499525, 13.338208 found way IDs:
# {"features": [{"geometry": null, "id": 318889287, "properties": {"cycleway:right": "track", "highway": "secondary", "lanes": "2", "lit": "yes", "maxspeed": "50", "name": "Lietzenburger Stra\u00dfe", "note": "\u00dcbergeordnete Stra\u00dfe, Stufe II", "oneway": "yes", "postal_code": "10789", "surface": "asphalt"}, "type": "Feature"}, {"geometry": null, "id": 362335283, "properties": {"landuse": "grass"}, "type": "Feature"}], "type": "FeatureCollection"}
#
#
# For location with coordinates 52.499371, 13.337167 found way IDs:
# {"features": [{"geometry": null, "id": 318889287, "properties": {"cycleway:right": "track", "highway": "secondary", "lanes": "2", "lit": "yes", "maxspeed": "50", "name": "Lietzenburger Stra\u00dfe", "note": "\u00dcbergeordnete Stra\u00dfe, Stufe II", "oneway": "yes", "postal_code": "10789", "surface": "asphalt"}, "type": "Feature"}, {"geometry": null, "id": 362335287, "properties": {"landuse": "grass"}, "type": "Feature"}], "type": "FeatureCollection"}
# For location with coordinates 52.499328, 13.336297 found way IDs:
# {"features": [{"geometry": null, "id": 318889282, "properties": {"cycleway:right": "track", "highway": "secondary", "lanes": "4", "lit": "yes", "maxspeed": "50", "name": "Lietzenburger Stra\u00dfe", "note": "\u00dcbergeordnete Stra\u00dfe, Stufe II", "oneway": "yes", "postal_code": "10789", "surface": "asphalt", "turn:lanes": "left|left|through|through"}, "type": "Feature"}, {"geometry": null, "id": 318889286, "properties": {"cycleway:right": "track", "highway": "secondary", "lanes": "3", "lit": "yes", "maxspeed": "50", "name": "Lietzenburger Stra\u00dfe", "note": "\u00dcbergeordnete Stra\u00dfe, Stufe II", "oneway": "yes", "postal_code": "10789", "surface": "asphalt", "turn:lanes": "left|through|none"}, "type": "Feature"}], "type": "FeatureCollection"}
#
#
# For location with coordinates 52.499351, 13.335804 found way IDs:
# {"features": [{"geometry": null, "id": 318889282, "properties": {"cycleway:right": "track", "highway": "secondary", "lanes": "4", "lit": "yes", "maxspeed": "50", "name": "Lietzenburger Stra\u00dfe", "note": "\u00dcbergeordnete Stra\u00dfe, Stufe II", "oneway": "yes", "postal_code": "10789", "surface": "asphalt", "turn:lanes": "left|left|through|through"}, "type": "Feature"}], "type": "FeatureCollection"}
#
#
# For location with coordinates 52.499356, 13.335765 found way IDs:
# {"features": [{"geometry": null, "id": 318889282, "properties": {"cycleway:right": "track", "highway": "secondary", "lanes": "4", "lit": "yes", "maxspeed": "50", "name": "Lietzenburger Stra\u00dfe", "note": "\u00dcbergeordnete Stra\u00dfe, Stufe II", "oneway": "yes", "postal_code": "10789", "surface": "asphalt", "turn:lanes": "left|left|through|through"}, "type": "Feature"}, {"geometry": null, "id": 572108487, "properties": {"foot": "crossing", "highway": "footway"}, "type": "Feature"}], "type": "FeatureCollection"}
#
#
# For location with coordinates 52.49938, 13.335589 found way IDs:
# {"features": [{"geometry": null, "id": 85127866, "properties": {"cycleway:right": "lane", "highway": "secondary", "lit": "yes", "maxspeed": "50", "name": "N\u00fcrnberger Stra\u00dfe", "oneway": "yes", "postal_code": "10777", "sidewalk": "right", "surface": "asphalt"}, "type": "Feature"}, {"geometry": null, "id": 85127868, "properties": {"cycleway:right": "lane", "highway": "tertiary", "lit": "yes", "maxspeed": "50", "name": "N\u00fcrnberger Stra\u00dfe", "oneway": "yes", "postal_code": "10789", "sidewalk": "right", "surface": "asphalt"}, "type": "Feature"}, {"geometry": null, "id": 318889282, "properties": {"cycleway:right": "track", "highway": "secondary", "lanes": "4", "lit": "yes", "maxspeed": "50", "name": "Lietzenburger Stra\u00dfe", "note": "\u00dcbergeordnete Stra\u00dfe, Stufe II", "oneway": "yes", "postal_code": "10789", "surface": "asphalt", "turn:lanes": "left|left|through|through"}, "type": "Feature"}], "type": "FeatureCollection"}
#
#
# For location with coordinates 52.499145, 13.335025 found way IDs:
# {"features": [{"geometry": null, "id": 85127874, "properties": {"cycleway:right": "track", "highway": "secondary", "lit": "yes", "maxspeed": "50", "name": "N\u00fcrnberger Stra\u00dfe", "oneway": "yes", "postal_code": "10777", "sidewalk": "right", "surface": "asphalt"}, "type": "Feature"}, {"geometry": null, "id": 97726187, "properties": {"boundary": "postal_code", "source": "http://wiki.openstreetmap.org/wiki/Import/Catalogue/Postleitzahlen_Deutschland_2010"}, "type": "Feature"}, {"geometry": null, "id": 362335290, "properties": {"landuse": "grass"}, "type": "Feature"}, {"geometry": null, "id": 387329044, "properties": {"electrified": "rail", "frequency": "0", "gauge": "1435", "layer": "-1", "level": "-1", "loading_gauge": "Kleinprofil", "maxspeed": "60", "name": "U3", "note": "TODO: check where exactly it goes underground", "operator": "Berliner Verkehrsbetriebe", "railway": "subway", "ref": "U3", "tunnel": "yes", "usage": "main", "voltage": "750"}, "type": "Feature"}], "type": "FeatureCollection"}
#
#
# For location with coordinates 52.498559, 13.334343 found way IDs:
# {"features": [{"geometry": null, "id": 4449439, "properties": {"cycleway:right": "track", "highway": "secondary", "lanes": "3", "lit": "yes", "maxspeed": "50", "name": "Spichernstra\u00dfe", "oneway": "yes", "postal_code": "10777", "sidewalk": "right", "surface": "asphalt"}, "type": "Feature"}, {"geometry": null, "id": 4616165, "properties": {"highway": "secondary", "lit": "yes", "maxspeed": "50", "name": "Spichernstra\u00dfe", "postal_code": "10777", "surface": "asphalt"}, "type": "Feature"}, {"geometry": null, "id": 24495448, "properties": {"highway": "residential", "lit": "yes", "maxspeed": "30", "name": "Schaperstra\u00dfe", "postal_code": "10719", "surface": "asphalt"}, "type": "Feature"}, {"geometry": null, "id": 85127874, "properties": {"cycleway:right": "track", "highway": "secondary", "lit": "yes", "maxspeed": "50", "name": "N\u00fcrnberger Stra\u00dfe", "oneway": "yes", "postal_code": "10777", "sidewalk": "right", "surface": "asphalt"}, "type": "Feature"}, {"geometry": null, "id": 528139677, "properties": {"electrified": "rail", "electrified:rail": "top", "frequency": "0", "gauge": "1435", "layer": "-1", "level": "-1", "loading_gauge": "Kleinprofil", "maxspeed": "60", "name": "U3", "note": "TODO: check where exactly it goes underground", "operator": "Berliner Verkehrsbetriebe", "railway": "subway", "ref": "U3", "tunnel": "yes", "usage": "main", "voltage": "750"}, "type": "Feature"}], "type": "FeatureCollection"}
#
#
# For location with coordinates 52.497966, 13.333567 found way IDs:
# {"features": [{"geometry": null, "id": 4449439, "properties": {"cycleway:right": "track", "highway": "secondary", "lanes": "3", "lit": "yes", "maxspeed": "50", "name": "Spichernstra\u00dfe", "oneway": "yes", "postal_code": "10777", "sidewalk": "right", "surface": "asphalt"}, "type": "Feature"}, {"geometry": null, "id": 382697147, "properties": {"landuse": "residential"}, "type": "Feature"}], "type": "FeatureCollection"}
#
#
# For location with coordinates 52.497437, 13.332765 found way IDs:
# {"features": [{"geometry": null, "id": 4449439, "properties": {"cycleway:right": "track", "highway": "secondary", "lanes": "3", "lit": "yes", "maxspeed": "50", "name": "Spichernstra\u00dfe", "oneway": "yes", "postal_code": "10777", "sidewalk": "right", "surface": "asphalt"}, "type": "Feature"}, {"geometry": null, "id": 362335286, "properties": {"landuse": "grass"}, "type": "Feature"}, {"geometry": null, "id": 382697147, "properties": {"landuse": "residential"}, "type": "Feature"}, {"geometry": null, "id": 528139677, "properties": {"electrified": "rail", "electrified:rail": "top", "frequency": "0", "gauge": "1435", "layer": "-1", "level": "-1", "loading_gauge": "Kleinprofil", "maxspeed": "60", "name": "U3", "note": "TODO: check where exactly it goes underground", "operator": "Berliner Verkehrsbetriebe", "railway": "subway", "ref": "U3", "tunnel": "yes", "usage": "main", "voltage": "750"}, "type": "Feature"}], "type": "FeatureCollection"}
#
#
# Got error: (<class 'overpass.errors.TimeoutError'>, TimeoutError(25,), <traceback object at 0x11639f848>)
# For location with coordinates 52.496629, 13.33142 found way IDs:
# {"features": [{"geometry": null, "id": 4449439, "properties": {"cycleway:right": "track", "highway": "secondary", "lanes": "3", "lit": "yes", "maxspeed": "50", "name": "Spichernstra\u00dfe", "oneway": "yes", "postal_code": "10777", "sidewalk": "right", "surface": "asphalt"}, "type": "Feature"}, {"geometry": null, "id": 362335286, "properties": {"landuse": "grass"}, "type": "Feature"}, {"geometry": null, "id": 528139677, "properties": {"electrified": "rail", "electrified:rail": "top", "frequency": "0", "gauge": "1435", "layer": "-1", "level": "-1", "loading_gauge": "Kleinprofil", "maxspeed": "60", "name": "U3", "note": "TODO: check where exactly it goes underground", "operator": "Berliner Verkehrsbetriebe", "railway": "subway", "ref": "U3", "tunnel": "yes", "usage": "main", "voltage": "750"}, "type": "Feature"}], "type": "FeatureCollection"}
#
#
# For location with coordinates 52.496448, 13.331094 found way IDs:
# {"features": [{"geometry": null, "id": 4449439, "properties": {"cycleway:right": "track", "highway": "secondary", "lanes": "3", "lit": "yes", "maxspeed": "50", "name": "Spichernstra\u00dfe", "oneway": "yes", "postal_code": "10777", "sidewalk": "right", "surface": "asphalt"}, "type": "Feature"}, {"geometry": null, "id": 85127865, "properties": {"bicycle": "yes", "foot": "designated", "footway": "crossing", "highway": "footway", "lit": "yes", "segregated": "yes"}, "type": "Feature"}, {"geometry": null, "id": 125667566, "properties": {"landuse": "grass"}, "type": "Feature"}, {"geometry": null, "id": 528139677, "properties": {"electrified": "rail", "electrified:rail": "top", "frequency": "0", "gauge": "1435", "layer": "-1", "level": "-1", "loading_gauge": "Kleinprofil", "maxspeed": "60", "name": "U3", "note": "TODO: check where exactly it goes underground", "operator": "Berliner Verkehrsbetriebe", "railway": "subway", "ref": "U3", "tunnel": "yes", "usage": "main", "voltage": "750"}, "type": "Feature"}], "type": "FeatureCollection"}

# %% [markdown]
# ## Osmium Test
#
# https://oslandia.com/en/2017/07/10/osm-tag-genome-how-are-osm-objects-tagged/

# %%
class OsmRouterExtractor(osmium.SimpleHandler):
    
    def __init__(self):
        osmium.SimpleHandler.__init__(self)
        self.wkbfab = osmium.geom.WKBFactory()
        self.ways_list = []
        self.node_list = []
        self.counter = 0
        self.road_types = ['motorway', 'trunk', 'primary', 'secondary', 'tertiary', 'road', 'residential', 
                           'motorway_link', 'trunk_link', 'primary_link', 'secondary_link', 'tertiary_link']
        
    def process_way(self, elem):
        #  elem.nodes return a node list:
        # https://docs.osmcode.org/pyosmium/latest/ref_osm.html?highlight=noderef#osmium.osm.NodeRef
        
        # TagList can't be converted to dict automatically, see:
        # https://github.com/osmcode/pyosmium/issues/106
        keys = {tag.k: tag.v for tag in elem.tags}
        # filter all types of car driving highways: https://wiki.openstreetmap.org/wiki/Key:highway?uselang=en-GBs
        if(('highway' in keys.keys())):
            if(keys['highway'] in self.road_types):
                nodes = [n.ref for n in elem.nodes] 
                wkb = self.wkbfab.create_linestring(elem)
                line = wkblib.loads(wkb, hex=True)
                names = [el.v for el in elem.tags if el.k == 'name' ]
                maxspeeds = [el.v for el in elem.tags if el.k == 'maxspeed']

                self.ways_list.append([elem.id,
                                       nodes,
                                       line,
                                       line.length,
                                       names[0] if len(names) > 0 else '',
                                       maxspeeds[0] if len(maxspeeds) > 0 else np.nan])
                
    def way(self, elem):
        self.process_way(elem)

# %%
# %%time

if(not os.path.exists('ways_berlin.pickle')):
    print('File ways_berlin.pickle NOT found. Recreating ways from pbf file')
    h = OsmRouterExtractor()

    h.apply_file("berlin-latest.osm.pbf", locations=True)

    colnames = ['way_id', 'nodes', 'line', 'line_length', 'name', 'maxspeed']
    ways_df = gpd.GeoDataFrame(h.ways_list, columns=colnames, geometry='line').set_index('way_id')
    
    with open('ways_berlin.pickle', 'wb') as f:
        pickle.dump(ways_df, f)
else:
    print('File ways_berlin.pickle found. Importing it locally')
    with open('ways_berlin.pickle', 'rb') as f:
        ways_df = pickle.load(f) 
        
display(ways_df.head())
# Out:
# File ways_berlin.pickle NOT found. Recreating ways from pbf file
#                                                      nodes  \
# way_id
# 4045150  [1234120411, 6375730236, 262876417, 262877047,...
# 4045194                             [21432547, 5986493261]
# 4045220  [28394961, 553334770, 3886937914, 29808849, 29...
# 4045223  [29808846, 21432567, 3889914802, 3889914958, 3...
# 4045243  [1822620447, 2845478638, 2845478635, 390192714...
#
#                                                       line  line_length  \
# way_id
# 4045150  LINESTRING (13.6051677 52.373418, 13.6055003 5...     0.007237
# 4045194  LINESTRING (13.5313455 52.4926226, 13.5315321 ...     0.001309
# 4045220  LINESTRING (13.5278334 52.4904272, 13.5263856 ...     0.006061
# 4045223  LINESTRING (13.523904 52.4828118, 13.5244956 5...     0.006651
# 4045243  LINESTRING (13.454214 52.5157088, 13.4543909 5...     0.004787
#
#                          name maxspeed
# way_id
# 4045150            Waldstraße       50
# 4045194  Ursula-Goetze-Straße       30
# 4045220        Hönower Straße       30
# 4045223   Gundelfinger Straße       30
# 4045243     Frankfurter Allee       50
# CPU times: user 43.2 s, sys: 504 ms, total: 43.7 s
# Wall time: 41.6 s

# %%
# TODO: Preprocess df to remove duplicate rows

# Identify street with same name
# If street name has only 1 speed, keep just 1. Maybe the longest linestring?

# %% [markdown]
# We can use now the lat longs of map matching to retrieve the maximum speed, but **it's too slow**

# %%
points = [[13.3709, 52.511582]] * 100 # possible size of gps trace
points = [Point(p_) for p_ in points]

# %%
# %%time
for p in points:
    min_distane_way_id = ways_df['line'].distance(p).idxmin() #168934839
display(ways_df.loc[min_distane_way_id])
# Out:
# CPU times: user 22.6 s, sys: 98.7 ms, total: 22.7 s
# Wall time: 22.8 s

# %% [markdown]
# Using [STRtree](https://shapely.readthedocs.io/en/stable/manual.html#str-packed-r-tree) for spatial indexing makes it **super fast**

# %%
# adding metadata to geometry: 
# https://github.com/Toblerity/Shapely/issues/618

for way_id, row in ways_df.iterrows():
    row['line'].name = way_id
    
tree = STRtree(ways_df['line'])

# %%
# %%time

points = [[13.3709, 52.511582]] * 100 # possible size of gps trace
points = [Point(p_) for p_ in points]

for p in points:
    way_response = tree.query(p)[0].name
display(ways_df.loc[way_response])
# Out:
# nodes       [26992494, 115774223, 411322982, 2021889550, 3...
# line        LINESTRING (13.3700849 52.5135155, 13.3701683 ...
# name                             Tunnel Tiergarten Spreebogen
# maxspeed                                                   50
# Name: 48859717, dtype: object
# CPU times: user 92.3 ms, sys: 3.39 ms, total: 95.7 ms
# Wall time: 94.9 ms

# %% [markdown]
# # Matching by pair <node - node = way>
#
# Didn't work

# %%
node_df_list = []
for ix, row in ways_df.iterrows():
    lon_l = row['line'].xy[0]
    lat_l = row['line'].xy[1]
    for i in range(len(lon_l)-1):
        p1 = Point(lon_l[i], lat_l[i])
        p2 = Point(lon_l[i+1], lat_l[i+1])
        node_df_list.append([
            row['nodes'][i],
            row['nodes'][i+1],
            p1,
            p2,
            LineString([p1, p2]),
            ix,
            row['name'],
            row['maxspeed']
        ])
        
columns = ['node_first', 'node_second', 'geom_point_first', 'geom_point_second', 'geom_line',
           'way_id', 'way_name', 'way_max_speed']
nodes_df = pd.DataFrame(node_df_list, columns=columns)

# %%
for way_id, row in nodes_df.iterrows():
    row['geom_line'].way_max_speed = row['way_max_speed']
    row['geom_line'].way_id = row['way_id']
    row['geom_line'].way_name = row['way_name']
    row['geom_line'].row_id = way_id
    
node_tree = STRtree(nodes_df['geom_line'])

# %% [markdown]
# No as well...because I'm calculating distance, it finds the closest points but I need to know the better `match` between the two linestrings

# %%
with open('temp.pickle', 'rb') as f:
        segments = pickle.load(f)

way_response = []
for line in segments:
    way_response.append(node_tree.query(line)[0].way_name)
way_response[:5]
# Out:
# ['Tunnel Tiergarten Spreebogen',
#  'Ben-Gurion-Straße',
#  'Ben-Gurion-Straße',
#  'Tiergartenstraße',
#  'Tiergartenstraße']

# %% [markdown]
# # Buffered OSM Linestrings

# %%
# first with whole way
pols = []
for way_id, row in ways_df.iterrows():
    p = Polygon(row['line'].buffer(.0001).exterior.coords)
    p.maxspeed = row['maxspeed']
    p.way_id = way_id
    p.name = row['name']
    pols.append(p)
    
ways_df2 = gpd.GeoDataFrame(ways_df, geometry=pols)
ways_df2 = ways_df2.loc[ways_df2['maxspeed'].astype(str).str.isnumeric()]
ways_df2['maxspeed'] = ways_df2['maxspeed'].astype(int)
display(ways_df2.head())
# Out:
#                                                      nodes  \
# way_id
# 4045150  [1234120411, 6375730236, 262876417, 262877047,...
# 4045194                             [21432547, 5986493261]
# 4045220  [28394961, 553334770, 3886937914, 29808849, 29...
# 4045223  [29808846, 21432567, 3889914802, 3889914958, 3...
# 4045243  [1822620447, 2845478638, 2845478635, 390192714...
#
#                                                       line  line_length  \
# way_id
# 4045150  LINESTRING (13.6051677 52.373418, 13.6055003 5...     0.007237
# 4045194  LINESTRING (13.5313455 52.4926226, 13.5315321 ...     0.001309
# 4045220  LINESTRING (13.5278334 52.4904272, 13.5263856 ...     0.006061
# 4045223  LINESTRING (13.523904 52.4828118, 13.5244956 5...     0.006651
# 4045243  LINESTRING (13.454214 52.5157088, 13.4543909 5...     0.004787
#
#                          name  maxspeed  \
# way_id
# 4045150            Waldstraße        50
# 4045194  Ursula-Goetze-Straße        30
# 4045220        Hönower Straße        30
# 4045223   Gundelfinger Straße        30
# 4045243     Frankfurter Allee        50
#
#                                                   geometry
# way_id
# 4045150  POLYGON ((13.60547638114791 52.37359699731509,...
# 4045194  POLYGON ((13.53143312069079 52.49393285118758,...
# 4045220  POLYGON ((13.5264488447908 52.48916763971058, ...
# 4045223  POLYGON ((13.52440013643137 52.48473817762692,...
# 4045243  POLYGON ((13.45440082383998 52.51579000704922,...

# %%
# %%time
for seg in segments:
    ways_df2.loc[ways_df2.contains(seg)]
# Out:
# CPU times: user 12.6 s, sys: 85.5 ms, total: 12.7 s
# Wall time: 12.8 s

# %% [markdown]
# Building an [R-Tree](http://toblerity.org/rtree/) for the buffered polygons.
#
# * If the tree doesn't find a perfect `contains`, we perform the same thing with just 1 point.
#
# <font color=green>It seems it works! :D</font>

# %%
idx = index.Index()

# Populate R-tree index with bounds of grid cells
for ix, cell in ways_df2.iterrows():
    # assuming cell is a shapely object
    idx.insert(ix, cell['geometry'].bounds)

# %%
# %%time
# Loop through each Shapely polygon
way_ids = []
for seg in segments:
    # Filter possible candidates using R-Tree
    idxs = idx.intersection(seg.bounds)
    # Now do actual intersection
    filter1 = ways_df2.loc[idxs].contains(seg)
    way_id = ways_df2.loc[filter1[filter1 == True].index]
    if(len(way_id) > 0):
        way_id = way_id['line_length'].idxmin()
    else:
        first_point = Point(seg.xy[0][1], seg.xy[1][1])
        idxs = idx.intersection(first_point.bounds)
        filter1 = ways_df2.loc[idxs].contains(first_point)
        way_id = ways_df2.loc[filter1[filter1 == True].index]['line_length'].idxmax()
    way_ids.append(way_id)

trace_speed = ways_df2.loc[way_ids]['maxspeed'].values
trace_speed[:5]
# Out:
# CPU times: user 260 ms, sys: 5.92 ms, total: 266 ms
# Wall time: 267 ms

# %%
with open('example_speeds.pickle', 'rb') as f:
    speeds = pickle.load(f)

# %%
# https://github.com/python-visualization/folium/blob/master/examples/Colormaps.ipynb
max_speed_cm = branca.colormap.LinearColormap( ['red', 'yellow', 'blue', 'purple'], 
                                        vmin=0, vmax=60, index=[10,20,50,60]) 
max_speed_cm.caption = 'Speed Km/h'

j = json.loads(gpd.GeoSeries(segments).buffer(.00005).to_json())
for elem, speed in zip(j['features'], speeds):
    elem['properties']['style'] = {}
    elem['properties']['style']['color'] = max_speed_cm(speed)
    elem['properties']['style']['fillOpacity'] = 1
    

map_ = folium.Map([52.521441,13.404057],
                  zoom_start=12)
traces = folium.features.GeoJson(j)
map_.add_child(traces)
map_.add_child(max_speed_cm)
map_
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
